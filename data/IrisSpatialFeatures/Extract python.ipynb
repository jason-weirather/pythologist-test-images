# %%
from pythologist_reader.formats.inform.custom import CellProjectInFormLineArea
from pythologist_reader.formats.inform.sets import CellProjectInForm

# %%
cpi = CellProjectInFormLineArea('pythologist.h5',mode='w')
cpi.read_path('Example',
              sample_name_index=-1,
              require=False,
              verbose=True,
              steps=76,
              project_name='IrisSpatialFeatures',
              channel_abbreviations={'PD-1 (Opal 540)':'PD1','PD-Ligand-1 (Opal 690)':'PDL1'},
              microns_per_pixel=0.496)
# Out:
# microns_per_pixel 0.496
# Reading sample /Users/jasonweirather/Source/pythologist-test-images/data/IrisSpatialFeatures/Example/MEL3 for sample MEL3
# Acquiring frame /Users/jasonweirather/Source/pythologist-test-images/data/IrisSpatialFeatures/Example/MEL3/MEL3_1_cell_seg_data.txt
# Reading text data.
# Finished assigning phenotype list.
# Tissue seg file is present.
# Finished setting the cell list regions are set.
# Finished setting the measurements.
# Finished reading score.
# Reading image data.
# Reading component images.
# Finished reading component images.
# Binary seg file present.
# Making cell-map filled-in.
# Finished cell-map.
# Making edge-map.
# Making dataframe of possible neighbors.
# Testing for edge.
# Finished edge-map.
# Set interaction map if appropriateFinished reading seg file present.
# setting tumor and stroma and margin
# Remaining areas after setting are 0
# finished tumor and stroma and margin
# Acquiring frame /Users/jasonweirather/Source/pythologist-test-images/data/IrisSpatialFeatures/Example/MEL3/MEL3_2_cell_seg_data.txt
# Reading text data.
# Finished assigning phenotype list.
# Tissue seg file is present.
# Finished setting the cell list regions are set.
# Finished setting the measurements.
# Finished reading score.
# Reading image data.
# Reading component images.
# Finished reading component images.
# Binary seg file present.
# Making cell-map filled-in.
# Finished cell-map.
# Making edge-map.
# Making dataframe of possible neighbors.
# Testing for edge.
# Finished edge-map.
# Set interaction map if appropriateFinished reading seg file present.
# setting tumor and stroma and margin
# Remaining areas after setting are 0
# finished tumor and stroma and margin
# Added sample ef24075008794b5dbc617a2b0c2b980b
# Reading sample /Users/jasonweirather/Source/pythologist-test-images/data/IrisSpatialFeatures/Example/MEL2 for sample MEL2
# Acquiring frame /Users/jasonweirather/Source/pythologist-test-images/data/IrisSpatialFeatures/Example/MEL2/MEL2_7_cell_seg_data.txt
# Reading text data.
# Finished assigning phenotype list.
# Tissue seg file is present.
# Finished setting the cell list regions are set.
# Finished setting the measurements.
# Finished reading score.
# Reading image data.
# Reading component images.
# Finished reading component images.
# Binary seg file present.
# Making cell-map filled-in.
# Finished cell-map.
# Making edge-map.
# Making dataframe of possible neighbors.
# Testing for edge.
# Finished edge-map.
# Set interaction map if appropriateFinished reading seg file present.
# setting tumor and stroma and margin
# Remaining areas after setting are 0
# finished tumor and stroma and margin
# Acquiring frame /Users/jasonweirather/Source/pythologist-test-images/data/IrisSpatialFeatures/Example/MEL2/MEL2_2_cell_seg_data.txt
# Reading text data.
# Finished assigning phenotype list.
# Tissue seg file is present.
# Finished setting the cell list regions are set.
# Finished setting the measurements.
# Finished reading score.
# Reading image data.
# Reading component images.
# Finished reading component images.
# Binary seg file present.
# Making cell-map filled-in.
# Finished cell-map.
# Making edge-map.
# Making dataframe of possible neighbors.
# Testing for edge.
# Finished edge-map.
# Set interaction map if appropriateFinished reading seg file present.
# setting tumor and stroma and margin
# Remaining areas after setting are 0
# finished tumor and stroma and margin
# Added sample 67f7c6522b5e44c9b2a7619bb9a70b4c

# %%
#cpi = CellProjectInForm('pythologist-whole-slide.h5',mode='w')
#cpi.read_path('Example',name_index=-1,require=False,verbose=True,project_name='IrisSpatialFeatures',
#              channel_abbreviations={'PD-1 (Opal 540)':'PD1','PD-Ligand-1 (Opal 690)':'PDL1'})

# %%
cpi.cdf
# Out:
#        cell_index     x     y region_label  \
# db_id
# 0               1   627     4        Tumor
# 1               2  1189     5        Tumor
# 2               3   199     5        Tumor
# 3               4   428     7        Tumor
# 4               5   460     5        Tumor
# 5               6   518     6        Tumor
# 6               7   664     5        Tumor
# 7               8   826     6        Tumor
# 8               9  1067     6        Tumor
# 9              10   160     6        Tumor
# 10             11   266     7        Tumor
# 11             12   916     8        Tumor
# 12             13  1007     7        Tumor
# 13             14  1028     8        Tumor
# 14             15    51     7        Tumor
# 15             16    62     7        Tumor
# 16             17   614     7        Tumor
# 17             18   762     8        Tumor
# 18             19  1081     9        Tumor
# 19             20  1293     8        Tumor
# 20             21  1304     8        Tumor
# 21             22   394     8        Tumor
# 22             23   582     8        Tumor
# 23             24  1217     9        Tumor
# 24             25   220    10        Tumor
# 25             26  1043     9        Tumor
# 26             27    97    10        Tumor
# 27             28   107    11        Tumor
# 28             29  1213    10        Tumor
# 29             30   643    11        Tumor
# ...           ...   ...   ...          ...
# 10096        2858    80  1013        Tumor
# 10097        2859   269  1014        Tumor
# 10098        2860  1009  1014       Margin
# 10099        2861   227  1012        Tumor
# 10100        2862  1225  1013        Tumor
# 10101        2863   125  1015        Tumor
# 10102        2864  1084  1019        Tumor
# 10103        2865  1373  1010        Tumor
# 10104        2866   197  1020        Tumor
# 10105        2867   740  1024        Tumor
# 10106        2868  1178  1020        Tumor
# 10107        2869    49  1020        Tumor
# 10108        2870  1208  1025        Tumor
# 10109        2871   331  1025        Tumor
# 10110        2872   523  1023        Tumor
# 10111        2873   247  1027        Tumor
# 10112        2874   650  1026        Tumor
# 10113        2875   349  1025        Tumor
# 10114        2876   877  1019       Margin
# 10115        2877    32  1028        Tumor
# 10116        2878   829  1028       Margin
# 10117        2879   987  1028       Margin
# 10118        2880  1251  1029        Tumor
# 10119        2881  1231  1030        Tumor
# 10120        2882   170  1030        Tumor
# 10121        2883   878  1031       Margin
# 10122        2884  1069  1024        Tumor
# 10123        2885   116  1033        Tumor
# 10124        2886   567    27       Stroma
# 10125        2887   465   148       Stroma
#
#                                                  regions  \
# db_id
# 0      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 1      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 2      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 3      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 4      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 5      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 6      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 7      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 8      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 9      {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 10     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 11     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 12     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 13     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 14     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 15     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 16     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 17     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 18     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 19     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 20     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 21     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 22     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 23     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 24     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 25     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 26     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 27     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 28     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# 29     {'Margin': 495640, 'Tumor': 947369, 'Stroma': ...
# ...                                                  ...
# 10096  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10097  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10098  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10099  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10100  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10101  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10102  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10103  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10104  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10105  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10106  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10107  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10108  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10109  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10110  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10111  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10112  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10113  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10114  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10115  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10116  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10117  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10118  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10119  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10120  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10121  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10122  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10123  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10124  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
# 10125  {'Margin': 501532, 'Tumor': 784027, 'Stroma': ...
#
#                 scored_calls                       phenotype_calls  \
# db_id
# 0      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 0, 'OTHER': 0, 'CD8+': 0}
# 1      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 2      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 3      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 4      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 5      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 6      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 7      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 8      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 9      {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 10     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 11     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 12     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 13     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 14     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 15     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 16     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 17     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 18     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 19     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 20     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 21     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 22     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 0, 'OTHER': 1, 'CD8+': 0}
# 23     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 24     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 25     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 26     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 27     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 28     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# 29     {'PD1': 0, 'PDL1': 0}  {'SOX10+': 1, 'OTHER': 0, 'CD8+': 0}
# ...                      ...                                   ...
# 10096  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10097  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10098  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10099  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10100  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10101  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10102  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10103  {'PD1': 1, 'PDL1': 1}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10104  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10105  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10106  {'PD1': 0, 'PDL1': 1}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10107  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10108  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10109  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10110  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10111  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10112  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10113  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10114  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10115  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10116  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10117  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10118  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10119  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10120  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10121  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10122  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10123  {'PD1': 0, 'PDL1': 0}  {'OTHER': 0, 'SOX10+': 1, 'CD8+': 0}
# 10124  {'PD1': 0, 'PDL1': 0}  {'OTHER': 1, 'SOX10+': 0, 'CD8+': 0}
# 10125  {'PD1': 1, 'PDL1': 1}  {'OTHER': 0, 'SOX10+': 0, 'CD8+': 1}
#
#                        channel_values  cell_area  edge_length  \
# db_id
# 0       {'PD1': 2.291, 'PDL1': 0.752}      278.0         48.0
# 1       {'PD1': 1.687, 'PDL1': 1.117}      248.0         38.0
# 2       {'PD1': 2.264, 'PDL1': 0.754}      602.0         64.0
# 3       {'PD1': 2.113, 'PDL1': 1.068}      575.0         58.0
# 4       {'PD1': 2.278, 'PDL1': 1.032}      520.0         59.0
# 5       {'PD1': 3.335, 'PDL1': 1.132}      489.0         58.0
# 10115   {'PD1': 8.113, 'PDL1': 0.589}      507.0         69.0
# 10116   {'PD1': 3.937, 'PDL1': 0.678}      463.0         58.0
# 10117   {'PD1': 4.586, 'PDL1': 0.606}      396.0         58.0
# 10118   {'PD1': 4.693, 'PDL1': 0.708}      378.0         55.0
# 10119   {'PD1': 3.945, 'PDL1': 0.616}      626.0         66.0
# 10120   {'PD1': 4.694, 'PDL1': 0.677}      274.0         40.0
# 10121   {'PD1': 4.704, 'PDL1': 0.691}      494.0         70.0
# 10122  {'PD1': 10.397, 'PDL1': 0.867}      438.0         54.0
# 10123   {'PD1': 4.421, 'PDL1': 0.553}     1225.0        136.0
# 10124   {'PD1': 5.806, 'PDL1': 0.429}      289.0         92.0
# 10125  {'PD1': 26.972, 'PDL1': 0.923}        NaN          NaN
#
#                                                neighbors frame_name  \
# db_id
# 0                            {31: 40, 1251: 21, 1272: 7}     MEL2_7
# 1                              {24: 9, 32: 30, 1259: 19}     MEL2_7
# 2                      {4: 18, 21: 20, 45: 11, 1273: 37}     MEL2_7
# 3                     {3: 20, 51: 23, 1262: 35, 1273: 8}     MEL2_7
# 4                           {47: 22, 1247: 22, 1278: 11}     MEL2_7
# 5                   {29: 13, 35: 25, 1274: 10, 1280: 20}     MEL2_7
# 6                           {33: 26, 1256: 11, 1260: 29}     MEL2_7
# 7                             {18: 20, 25: 22, 1271: 17}     MEL2_7
# 8                           {32: 19, 1265: 32, 1277: 24}     MEL2_7
# 9                                      {36: 4, 1269: 47}     MEL2_7
# 10                                  {1249: 17, 1275: 30}     MEL2_7
# 11                          {13: 17, 1276: 22, 1286: 17}     MEL2_7
# 12                     {12: 17, 25: 9, 34: 18, 1276: 11}     MEL2_7
# 13                             {15: 15, 43: 4, 1253: 29}     MEL2_7
# 14                      {14: 16, 26: 15, 43: 25, 44: 13}     MEL2_7
# 15            {22: 8, 29: 6, 42: 20, 1264: 18, 1266: 20}     MEL2_7
# 16                        {1248: 26, 1263: 37, 1283: 15}     MEL2_7
# 17                             {8: 21, 30: 38, 1271: 18}     MEL2_7
# 18                 {20: 23, 1257: 33, 1268: 9, 1281: 10}     MEL2_7
# 19                           {19: 25, 1258: 5, 1268: 35}     MEL2_7
# 20                               {3: 18, 45: 27, 53: 17}     MEL2_7
# 21                      {16: 8, 37: 32, 48: 2, 1264: 33}     MEL2_7
# 22                                              {28: 50}     MEL2_7
# 23                                      {2: 9, 1259: 44}     MEL2_7
# 24                      {8: 22, 13: 8, 34: 27, 1271: 13}     MEL2_7
# 25                       {15: 14, 27: 31, 41: 9, 44: 19}     MEL2_7
# 26                   {26: 30, 41: 26, 1277: 22, 1292: 4}     MEL2_7
# 27                                      {23: 49, 31: 40}     MEL2_7
# 28                    {6: 13, 16: 6, 1266: 25, 1274: 18}     MEL2_7
# 29                                    {18: 38, 1261: 34}     MEL2_7
# ...                                                  ...        ...
# 10096  {1964: 16, 1965: 29, 2019: 28, 2831: 20, 2872:...     MEL3_1
# 10097  {1930: 16, 1946: 17, 1968: 22, 1985: 11, 2014:...     MEL3_1
f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 9      67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 10     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 11     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 12     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 13     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 14     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 15     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 16     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 17     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 18     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 19     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 20     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 21     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 22     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 23     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 24     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 25     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 26     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 27     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 28     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# 29     67f7c6522b5e44c9b2a7619bb9a70b4c  a7752dff57414201bef9711b26a848e9
# ...                                 ...                               ...
# 10096  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10097  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10098  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10099  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10100  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10101  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10102  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10103  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10104  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10105  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10106  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10107  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10108  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10109  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10110  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10111  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10112  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10113  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10114  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10115  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10116  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10117  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10118  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10119  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10120  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10121  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10122  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10123  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10124  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
# 10125  ef24075008794b5dbc617a2b0c2b980b  a7752dff57414201bef9711b26a848e9
#
#       phenotype_label   frame_shape
# db_id
# 0                 NaN  (1040, 1392)
# 1              SOX10+  (1040, 1392)
# 2              SOX10+  (1040, 1392)
# 3              SOX10+  (1040, 1392)
# 4              SOX10+  (1040, 1392)
# 5              SOX10+  (1040, 1392)
# 6              SOX10+  (1040, 1392)
# 7              SOX10+  (1040, 1392)
# 8              SOX10+  (1040, 1392)
# 9              SOX10+  (1040, 1392)
# 10             SOX10+  (1040, 1392)
# 11             SOX10+  (1040, 1392)
# 12             SOX10+  (1040, 1392)
# 13             SOX10+  (1040, 1392)
# 14             SOX10+  (1040, 1392)
# 15             SOX10+  (1040, 1392)
# 16             SOX10+  (1040, 1392)
# 17             SOX10+  (1040, 1392)
# 18             SOX10+  (1040, 1392)
# 19             SOX10+  (1040, 1392)
# 20             SOX10+  (1040, 1392)
# 21             SOX10+  (1040, 1392)
# 22              OTHER  (1040, 1392)
# 23             SOX10+  (1040, 1392)
# 24             SOX10+  (1040, 1392)
# 25             SOX10+  (1040, 1392)
# 26             SOX10+  (1040, 1392)
# 27             SOX10+  (1040, 1392)
# 28             SOX10+  (1040, 1392)
# 29             SOX10+  (1040, 1392)
# ...               ...           ...
# 10096          SOX10+  (1040, 1392)
# 10097          SOX10+  (1040, 1392)
# 10098          SOX10+  (1040, 1392)
# 10099          SOX10+  (1040, 1392)
# 10100          SOX10+  (1040, 1392)
# 10101          SOX10+  (1040, 1392)
# 10102          SOX10+  (1040, 1392)
# 10103          SOX10+  (1040, 1392)
# 10104          SOX10+  (1040, 1392)
# 10105          SOX10+  (1040, 1392)
# 10106          SOX10+  (1040, 1392)
# 10107          SOX10+  (1040, 1392)
# 10108          SOX10+  (1040, 1392)
# 10109          SOX10+  (1040, 1392)
# 10110          SOX10+  (1040, 1392)
# 10111          SOX10+  (1040, 1392)
# 10112          SOX10+  (1040, 1392)
# 10113          SOX10+  (1040, 1392)
# 10114          SOX10+  (1040, 1392)
# 10115          SOX10+  (1040, 1392)
# 10116          SOX10+  (1040, 1392)
# 10117          SOX10+  (1040, 1392)
# 10118          SOX10+  (1040, 1392)
# 10119          SOX10+  (1040, 1392)
# 10120          SOX10+  (1040, 1392)
# 10121          SOX10+  (1040, 1392)
# 10122          SOX10+  (1040, 1392)
# 10123          SOX10+  (1040, 1392)
# 10124           OTHER  (1040, 1392)
# 10125            CD8+  (1040, 1392)
#
# [10126 rows x 19 columns]

# %%
cpi.cdf.to_hdf('pythologist.cdf.h5','data')

# %%
cpi
